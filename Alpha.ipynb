# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.fftpack import fft,fftshift,fftfreq,ifft
from scipy import signal
from scipy import stats

# %%
file = pd.read_csv('alpha.csv')
df = pd.DataFrame(file)
df.drop(df.columns[0],axis=1,inplace=True)
df.head(3)
# Out:
#         AF3        F7        F3       FC5        T7        P7        O1  \
# 0  0.000004  0.000006  0.000022  0.000004  0.000008  0.000002  0.000006
# 1  0.000004  0.000007  0.000021  0.000004  0.000009  0.000002  0.000006
# 2  0.000004  0.000007  0.000020  0.000004  0.000009  0.000002  0.000007
#
#          O2        P8        T8       FC6        F4        F8       AF4
# 0  0.000002  0.000008  0.000007  0.000011  0.000022  0.000018  0.000014
# 1  0.000002  0.000008  0.000007  0.000010  0.000023  0.000018  0.000014
# 2  0.000002  0.000008  0.000006  0.000010  0.000024  0.000017  0.000015

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 921600 entries, 0 to 921599
# Data columns (total 14 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   AF3     921600 non-null  float64
#  1   F7      921600 non-null  float64
#  2   F3      921600 non-null  float64
#  3   FC5     921600 non-null  float64
#  4   T7      921600 non-null  float64
#  5   P7      921600 non-null  float64
#  6   O1      921600 non-null  float64
#  7   O2      921600 non-null  float64
#  8   P8      921600 non-null  float64
#  9   T8      921600 non-null  float64
#  10  FC6     921600 non-null  float64
#  11  F4      921600 non-null  float64
#  12  F8      921600 non-null  float64
#  13  AF4     921600 non-null  float64
# dtypes: float64(14)
# memory usage: 98.4 MB

# %%
des = df.describe()

# %%
df.boxplot()
plt.show()

# %%
x = np.arange(0,7200,(1/128))

for i in range(len(df.columns)):
    plt.figure(figsize=(20,5))
    
    plt.subplot(1,2,1)
    plt.plot(x[:499201],df[df.columns[i]][:499201],'go')
    plt.xlabel('T(time)')
    plt.ylabel('Amp')
    plt.title('Signal in Time Domain(CLASS-2)')
    plt.subplot(1,2,2)
    plt.plot(x[499201:],df[df.columns[i]][499201:],'yo')
    plt.xlabel('T(time)')
    plt.ylabel('Amp')
    plt.title('Signal in Time Domain(CLASS-1)')
    plt.show()
    print("This is the ALPHA Band of ",df.columns[i])
    print('summery :(class-2) ','summery :(class-1)')
    print(pd.concat([pd.DataFrame(df[df.columns[i]][:499201].describe()),pd.DataFrame(df[df.columns[i]][499201:].describe())],axis=1))
# Out:
# This is the ALPHA Band of  AF3
# summery :(class-2)  summery :(class-1)
#                 AF3           AF3
# count  4.992010e+05  4.223990e+05
# mean   8.562482e-06  8.593719e-06
# std    1.725295e-05  1.877509e-05
# min    9.038945e-09  6.990248e-09
# 25%    3.711473e-06  3.928326e-06
# 50%    6.145538e-06  6.505950e-06
# 75%    9.734627e-06  1.017582e-05
# max    1.084834e-03  1.541220e-03
# This is the ALPHA Band of  F7
# summery :(class-2)  summery :(class-1)
#                  F7            F7
# count  4.992010e+05  4.223990e+05
# mean   1.282008e-05  1.067373e-05
# std    3.742814e-05  1.263678e-05
# std    9.601418e-06  1.189784e-05
# min    5.294789e-09  3.675967e-09
# 25%    1.986183e-06  2.199072e-06
# 50%    3.200952e-06  3.597791e-06
# 75%    4.916514e-06  5.633881e-06
# max    7.431227e-04  5.699657e-04
# This is the ALPHA Band of  T8
# summery :(class-2)  summery :(class-1)
#                  T8            T8
# count  4.992010e+05  4.223990e+05
# mean   2.944685e-06  3.559644e-06
# std    7.126096e-06  6.197140e-06
# min    1.052096e-09  3.182720e-09
# 25%    1.247923e-06  1.420401e-06
# 50%    2.028521e-06  2.342409e-06
# 75%    3.142701e-06  3.778611e-06
# max    5.124712e-04  3.462783e-04
# This is the ALPHA Band of  FC6
# summery :(class-2)  summery :(class-1)
#                 FC6           FC6
# count  4.992010e+05  4.223990e+05
# mean   7.894314e-06  8.761740e-06
# std    1.778189e-05  1.468219e-05
# min    3.504624e-09  9.791048e-09
# 25%    3.831500e-06  4.298697e-06
# 50%    6.129166e-06  6.889058e-06
# 75%    9.145572e-06  1.043478e-05
# max    1.267419e-03  1.173390e-03
# This is the ALPHA Band of  F4
# summery :(class-2)  summery :(class-1)
#                  F4            F4
# count  4.992010e+05  4.223990e+05
# mean   1.013038e-05  1.083871e-05
# std    2.949199e-05  2.258290e-05
# min    7.885406e-09  8.064163e-09
# 25%    4.410207e-06  4.710084e-06
# 50%    7.062165e-06  7.692070e-06
# 75%    1.063599e-05  1.201978e-05
# max    2.285447e-03  1.000296e-03
# This is the ALPHA Band of  F8
# summery :(class-2)  summery :(class-1)
#                  F8            F8
# count  4.992010e+05  4.223990e+05
# mean   7.962324e-06  1.119026e-05
# std    1.496272e-05  2.254194e-05
# min    1.363985e-08  5.968293e-09
# 25%    3.343773e-06  3.703621e-06
# 50%    5.333210e-06  6.077071e-06
# 75%    8.010173e-06  9.987243e-06
# max    9.193172e-04  1.196171e-03
# This is the ALPHA Band of  AF4
# summery :(class-2)  summery :(class-1)
#                 AF4           AF4
# count  4.992010e+05  4.223990e+05
# mean   1.087798e-05  1.268976e-05
# std    1.861431e-05  1.726235e-05
# min    9.943380e-09  1.641161e-08
# 25%    5.264499e-06  5.731327e-06
# 50%    8.515376e-06  9.252648e-06
# 75%    1.280418e-05  1.421137e-05
# max    1.152449e-03  1.062350e-03

# %%
b,a = signal.butter(10,[8*(2*np.pi),12*(2*np.pi)],btype='bandpass',analog=True,output='ba')

# %%
for i in range(len(df.columns)):
    plt.figure(figsize=(17,5))
    
    plt.subplot(1,3,1)
    w2,h2 = signal.freqs(b,a,worN=499201)
    y2 = np.abs(fft(np.array(df[df.columns[i]][:499201]))*h2)
    plt.plot(w2,y2,'y',label='class-2')
    plt.xlabel("W(rad/s)")
    plt.ylabel("Amp")
    plt.title('Amplitude spectrum(class-2)')
    
    plt.subplot(1,3,2)
    w1,h1 = signal.freqs(b,a,worN=(921600-499201))
    y1 = np.abs(fft(np.array(df[df.columns[i]][499201:]))*h1)
    plt.plot(w1,y1,'b',label='class-1')
    plt.xlabel("W(rad/s)")
    plt.title('Amplitude spectrum(class-1)')
  
    plt.subplot(1,3,3)
    plt.plot(w2,y2,'y',label='class-2')
    plt.plot(w1,y1,'b',label='class-1')
    plt.xlabel("W(rad/s)")
    plt.title('Amplitude spectrum')
    plt.legend(loc='best')
    
    plt.show()
    
    print("This is the ALPHA Band of ",df.columns[i])
# Out:
# This is the ALPHA Band of  AF3
# This is the ALPHA Band of  F7
# This is the ALPHA Band of  F3
# This is the ALPHA Band of  FC5
# This is the ALPHA Band of  T7
# This is the ALPHA Band of  P7
# This is the ALPHA Band of  O1
# This is the ALPHA Band of  O2
# This is the ALPHA Band of  P8
# This is the ALPHA Band of  T8
# This is the ALPHA Band of  FC6
# This is the ALPHA Band of  F4
# This is the ALPHA Band of  F8
# This is the ALPHA Band of  AF4

# %%
for i in range(len(df.columns)):
    plt.figure(figsize=(17,5))
    
    plt.subplot(1,3,1)
    w2,h2 = signal.freqs(b,a,worN=499201)
    y2 = 20*np.log10(np.abs(fft(np.array(df[df.columns[i]][:499201]))*h2)**2)
    plt.plot(w2,y2,'y',label='class-2')
    plt.xlabel("W(rad/s)")
    plt.ylabel("Amp(in db(20*log10))")
    plt.title('PSD(class-2)')
    
    plt.subplot(1,3,2)
    w1,h1 = signal.freqs(b,a,worN=(921600-499201))
    y1 = 20*np.log10(np.abs(fft(np.array(df[df.columns[i]][499201:]))*h1)**2)
    plt.plot(w1,y1,'b',label='class-1')
    plt.xlabel("W(rad/s)")
    plt.title('PSD(class-1)')
  
    plt.subplot(1,3,3)
    plt.plot(w2,y2,'y',label='class-2')
    plt.plot(w1,y1,'b',label='class-1')
    plt.xlabel("W(rad/s)")
    plt.title('PSD')
    plt.legend(loc='best')
    
    plt.show()
    print('This is the PSD of Alpha Band of ',df.columns[i])
# Out:
# This is the PSD of Alpha Band of  AF3
# This is the PSD of Alpha Band of  F7
# This is the PSD of Alpha Band of  F3
# This is the PSD of Alpha Band of  FC5
# This is the PSD of Alpha Band of  T7
# This is the PSD of Alpha Band of  P7
# This is the PSD of Alpha Band of  O1
# This is the PSD of Alpha Band of  O2
# This is the PSD of Alpha Band of  P8
# This is the PSD of Alpha Band of  T8
# This is the PSD of Alpha Band of  FC6
# This is the PSD of Alpha Band of  F4
# This is the PSD of Alpha Band of  F8
# This is the PSD of Alpha Band of  AF4

# %%
for i in range(len(df.columns)):
    plt.figure(figsize=(20,5))
    plt.subplot(1,2,1)
    w2,h2 = signal.freqs(b,a,worN=499201)
    y2 = np.angle(fft(np.array(df[df.columns[i]][:499201]))*h2)
    plt.plot(w2,y2,'y')
    plt.xlabel('W(rad/sec)')
    plt.ylabel('Phase(rad)')
    plt.title('Phase spectrum(class-2)')
    
    plt.subplot(1,2,2)
    w1,h1 = signal.freqs(b,a,worN=(921600-499201))
    y1 = np.angle(fft(np.array(df[df.columns[i]][499201:]))*h1)
    plt.plot(w1,y1,'b')
    plt.xlabel("W(rad/s)")
    plt.ylabel('Phase(rad)')
    plt.title('Phase spectrum(class-1)')
    
    plt.show()
    print("This is the ALPHA Band of ",df.columns[i])
# Out:
# This is the ALPHA Band of  AF3
# This is the ALPHA Band of  F7
# This is the ALPHA Band of  F3
# This is the ALPHA Band of  FC5
# This is the ALPHA Band of  T7
# This is the ALPHA Band of  P7
# This is the ALPHA Band of  O1
# This is the ALPHA Band of  O2
# This is the ALPHA Band of  P8
# This is the ALPHA Band of  T8
# This is the ALPHA Band of  FC6
# This is the ALPHA Band of  F4
# This is the ALPHA Band of  F8
# This is the ALPHA Band of  AF4
