# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.fftpack import fft,fftshift,fftfreq,ifft
from scipy import signal
from scipy import stats

# %%
file = pd.read_csv('delta.csv')
df = pd.DataFrame(file)
df.drop(df.columns[0],axis=1,inplace=True)
df.head(3)
# Out:
#         AF3        F7        F3       FC5        T7        P7        O1  \
# 0  0.000019  0.000036  0.000062  0.000009  0.000017  0.000002  0.000022
# 1  0.000019  0.000034  0.000052  0.000011  0.000015  0.000003  0.000018
# 2  0.000018  0.000029  0.000043  0.000014  0.000015  0.000006  0.000015
#
#          O2        P8        T8       FC6        F4        F8       AF4
# 0  0.000006  0.000008  0.000003  0.000048  0.000038  0.000003  0.000039
# 1  0.000005  0.000006  0.000002  0.000043  0.000040  0.000006  0.000044
# 2  0.000005  0.000004  0.000004  0.000037  0.000041  0.000012  0.000047

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 921600 entries, 0 to 921599
# Data columns (total 14 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   AF3     921600 non-null  float64
#  1   F7      921600 non-null  float64
#  2   F3      921600 non-null  float64
#  3   FC5     921600 non-null  float64
#  4   T7      921600 non-null  float64
#  5   P7      921600 non-null  float64
#  6   O1      921600 non-null  float64
#  7   O2      921600 non-null  float64
#  8   P8      921600 non-null  float64
#  9   T8      921600 non-null  float64
#  10  FC6     921600 non-null  float64
#  11  F4      921600 non-null  float64
#  12  F8      921600 non-null  float64
#  13  AF4     921600 non-null  float64
# dtypes: float64(14)
# memory usage: 98.4 MB

# %%
des = df.describe()

# %%
df.boxplot()
plt.show()

# %%
x = np.arange(0,7200,(1/128))

for i in range(len(df.columns)):
    plt.figure(figsize=(20,5))
    
    plt.subplot(1,2,1)
    plt.plot(x[:499201],df[df.columns[i]][:499201],'go')
    plt.xlabel('T(time)')
    plt.ylabel('Amp')
    plt.title('Signal in Time Domain(CLASS-2)')
    plt.subplot(1,2,2)
    plt.plot(x[499201:],df[df.columns[i]][499201:],'yo')
    plt.xlabel('T(time)')
    plt.ylabel('Amp')
    plt.title('Signal in Time Domain(CLASS-1)')
    plt.show()
    print("This is the DELTA Band of ",df.columns[i])
    print('summery :(class-2) ','summery :(class-1)')
    print(pd.concat([pd.DataFrame(df[df.columns[i]][:499201].describe()),pd.DataFrame(df[df.columns[i]][499201:].describe())],axis=1))
# Out:
# This is the DELTA Band of  AF3
# summery :(class-2)  summery :(class-1)
#                 AF3           AF3
# count  4.992010e+05  4.223990e+05
# mean   1.653995e-05  1.601351e-05
# std    4.333002e-05  3.582089e-05
# min    1.197571e-08  9.446187e-09
# 25%    7.147731e-06  7.456800e-06
# 50%    1.174142e-05  1.227812e-05
# 75%    1.850734e-05  1.918658e-05
# max    7.110095e-03  5.101276e-03
# This is the DELTA Band of  F7
# summery :(class-2)  summery :(class-1)
#                  F7            F7
# count  4.992010e+05  4.223990e+05
# mean   2.418813e-05  2.048346e-05
# std    7.248678e-05  2.452493e-05
# min    7.880990e-09  1.332076e-08
# 50%    6.156275e-06  6.760046e-06
# 75%    9.399197e-06  1.053127e-05
# max    1.695998e-03  1.903348e-03
# This is the DELTA Band of  T8
# summery :(class-2)  summery :(class-1)
#                  T8            T8
# count  4.992010e+05  4.223990e+05
# mean   5.497208e-06  6.552248e-06
# std    1.432174e-05  1.202737e-05
# min    5.743096e-09  5.062632e-09
# 25%    2.430769e-06  2.731932e-06
# 50%    3.908939e-06  4.468320e-06
# 75%    5.944168e-06  7.071876e-06
# max    1.741306e-03  1.143997e-03
# This is the DELTA Band of  FC6
# summery :(class-2)  summery :(class-1)
#                 FC6           FC6
# count  4.992010e+05  4.223990e+05
# mean   1.518303e-05  1.609914e-05
# std    4.074467e-05  2.846833e-05
# min    2.061335e-08  2.408595e-08
# 25%    7.386817e-06  8.094857e-06
# 50%    1.174817e-05  1.294001e-05
# 75%    1.745784e-05  1.946550e-05
# max    5.520461e-03  3.753787e-03
# This is the DELTA Band of  F4
# summery :(class-2)  summery :(class-1)
#                  F4            F4
# count  4.992010e+05  4.223990e+05
# mean   1.877797e-05  1.988955e-05
# std    5.614097e-05  4.198802e-05
# min    1.120874e-08  2.223534e-08
# 25%    8.575445e-06  9.054355e-06
# 50%    1.368880e-05  1.467353e-05
# 75%    2.046287e-05  2.258939e-05
# max    6.428707e-03  3.356646e-03
# This is the DELTA Band of  F8
# summery :(class-2)  summery :(class-1)
#                  F8            F8
# count  4.992010e+05  4.223990e+05
# mean   1.514585e-05  2.054902e-05
# std    3.230684e-05  4.346858e-05
# min    1.338620e-08  1.092577e-08
# 25%    6.491793e-06  7.079583e-06
# 50%    1.033143e-05  1.154361e-05
# 75%    1.543499e-05  1.858048e-05
# max    2.811438e-03  4.279986e-03
# This is the DELTA Band of  AF4
# summery :(class-2)  summery :(class-1)
#                 AF4           AF4
# count  4.992010e+05  4.223990e+05
# mean   2.043788e-05  2.360652e-05
# std    3.938036e-05  3.389551e-05
# min    1.301626e-08  4.669351e-08
# 25%    1.005515e-05  1.088293e-05
# 50%    1.614463e-05  1.746588e-05
# 75%    2.425286e-05  2.670252e-05
# max    3.468073e-03  3.907486e-03

# %%
b,a = signal.butter(10,[0.5*(2*np.pi),3*(2*np.pi)],btype='bandpass',analog=True,output='ba')

# %%
for i in range(len(df.columns)):
    plt.figure(figsize=(17,5))
    
    plt.subplot(1,3,1)
    w2,h2 = signal.freqs(b,a,worN=499201)
    y2 = np.abs(fft(np.array(df[df.columns[i]][:499201]))*h2)
    plt.plot(w2,y2,'y',label='class-2')
    plt.xlabel("W(rad/s)")
    plt.ylabel("Amp")
    plt.title('Amplitude spectrum(class-2)')
    
    plt.subplot(1,3,2)
    w1,h1 = signal.freqs(b,a,worN=(921600-499201))
    y1 = np.abs(fft(np.array(df[df.columns[i]][499201:]))*h1)
    plt.plot(w1,y1,'b',label='class-1')
    plt.xlabel("W(rad/s)")
    plt.title('Amplitude spectrum(class-1)')
  
    plt.subplot(1,3,3)
    plt.plot(w2,y2,'y',label='class-2')
    plt.plot(w1,y1,'b',label='class-1')
    plt.xlabel("W(rad/s)")
    plt.title('Amplitude spectrum')
    plt.legend(loc='best')
    
    plt.show()
    print("This is the DELTA Band of ",df.columns[i])
# Out:
# This is the DELTA Band of  AF3
# This is the DELTA Band of  F7
# This is the DELTA Band of  F3
# This is the DELTA Band of  FC5
# This is the DELTA Band of  T7
# This is the DELTA Band of  P7
# This is the DELTA Band of  O1
# This is the DELTA Band of  O2
# This is the DELTA Band of  P8
# This is the DELTA Band of  T8
# This is the DELTA Band of  FC6
# This is the DELTA Band of  F4
# This is the DELTA Band of  F8
# This is the DELTA Band of  AF4

# %%
for i in range(len(df.columns)):
    plt.figure(figsize=(17,5))
    
    plt.subplot(1,3,1)
    w2,h2 = signal.freqs(b,a,worN=499201)
    y2 = 20*np.log10(np.abs(fft(np.array(df[df.columns[i]][:499201]))*h2)**2)
    plt.plot(w2,y2,'y',label='class-2')
    plt.xlabel("W(rad/s)")
    plt.ylabel("Amp(in db(20*log10))")
    plt.title('PSD(class-2)')
    
    plt.subplot(1,3,2)
    w1,h1 = signal.freqs(b,a,worN=(921600-499201))
    y1 = 20*np.log10(np.abs(fft(np.array(df[df.columns[i]][499201:]))*h1)**2)
    plt.plot(w1,y1,'b',label='class-1')
    plt.xlabel("W(rad/s)")
    plt.title('PSD(class-1)')
  
    plt.subplot(1,3,3)
    plt.plot(w2,y2,'y',label='class-2')
    plt.plot(w1,y1,'b',label='class-1')
    plt.xlabel("W(rad/s)")
    plt.title('PSD')
    plt.legend(loc='best')
    
    plt.show()
    print('This is the PSD of DELTA Band of ',df.columns[i])
# Out:
# This is the PSD of DELTA Band of  AF3
# This is the PSD of DELTA Band of  F7
# This is the PSD of DELTA Band of  F3
# This is the PSD of DELTA Band of  FC5
# This is the PSD of DELTA Band of  T7
# This is the PSD of DELTA Band of  P7
# This is the PSD of DELTA Band of  O1
# This is the PSD of DELTA Band of  O2
# This is the PSD of DELTA Band of  P8
# This is the PSD of DELTA Band of  T8
# This is the PSD of DELTA Band of  FC6
# This is the PSD of DELTA Band of  F4
# This is the PSD of DELTA Band of  F8
# This is the PSD of DELTA Band of  AF4

# %%
for i in range(len(df.columns)):
    plt.figure(figsize=(20,5))
    plt.subplot(1,2,1)
    w2,h2 = signal.freqs(b,a,worN=499201)
    y2 = np.angle(fft(np.array(df[df.columns[i]][:499201]))*h2)
    plt.plot(w2,y2,'y')
    plt.xlabel('W(rad/sec)')
    plt.ylabel('Phase(rad)')
    plt.title('Phase spectrum(class-2)')
    
    plt.subplot(1,2,2)
    w1,h1 = signal.freqs(b,a,worN=(921600-499201))
    y1 = np.angle(fft(np.array(df[df.columns[i]][499201:]))*h1)
    plt.plot(w1,y1,'b')
    plt.xlabel("W(rad/s)")
    plt.ylabel('Phase(rad)')
    plt.title('Phase spectrum(class-1)')
    
    plt.show()
    print("This is the DELTA Band of ",df.columns[i])
# Out:
# This is the DELTA Band of  AF3
# This is the DELTA Band of  F7
# This is the DELTA Band of  F3
# This is the DELTA Band of  FC5
# This is the DELTA Band of  T7
# This is the DELTA Band of  P7
# This is the DELTA Band of  O1
# This is the DELTA Band of  O2
# This is the DELTA Band of  P8
# This is the DELTA Band of  T8
# This is the DELTA Band of  FC6
# This is the DELTA Band of  F4
# This is the DELTA Band of  F8
# This is the DELTA Band of  AF4
