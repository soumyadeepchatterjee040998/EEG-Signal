# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.fftpack import fft,fftshift,fftfreq,ifft
from scipy import signal
from scipy import stats

# %%
file = pd.read_csv('beta.csv')
df = pd.DataFrame(file)
df.drop(df.columns[0],axis=1,inplace=True)
df.head(3)
# Out:
#         AF3        F7        F3       FC5        T7        P7        O1  \
# 0  0.000033  0.000027  0.000034  0.000016  0.000011  0.000008  0.000025
# 1  0.000027  0.000027  0.000028  0.000013  0.000008  0.000008  0.000021
# 2  0.000021  0.000026  0.000024  0.000010  0.000007  0.000007  0.000017
#
#          O2            P8        T8       FC6        F4        F8       AF4
# 0  0.000006  5.680113e-07  0.000004  0.000007  0.000013  0.000013  0.000025
# 1  0.000004  2.134852e-06  0.000004  0.000012  0.000015  0.000007  0.000023
# 2  0.000003  3.916843e-06  0.000006  0.000019  0.000016  0.000004  0.000020

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 921600 entries, 0 to 921599
# Data columns (total 14 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   AF3     921600 non-null  float64
#  1   F7      921600 non-null  float64
#  2   F3      921600 non-null  float64
#  3   FC5     921600 non-null  float64
#  4   T7      921600 non-null  float64
#  5   P7      921600 non-null  float64
#  6   O1      921600 non-null  float64
#  7   O2      921600 non-null  float64
#  8   P8      921600 non-null  float64
#  9   T8      921600 non-null  float64
#  10  FC6     921600 non-null  float64
#  11  F4      921600 non-null  float64
#  12  F8      921600 non-null  float64
#  13  AF4     921600 non-null  float64
# dtypes: float64(14)
# memory usage: 98.4 MB

# %%
des = df.describe()

# %%
df.boxplot()
plt.show()

# %%
x = np.arange(0,7200,(1/128))

for i in range(len(df.columns)):
    plt.figure(figsize=(20,5))
    plt.subplot(1,2,1)
    
    plt.plot(x[:499201],df[df.columns[i]][:499201],'go')    
    plt.xlabel('T(time)')
    plt.ylabel('Amp')
    plt.title('Signal in Time Domain(CLASS-2)')
    
    plt.subplot(1,2,2)
    plt.plot(x[499201:],df[df.columns[i]][499201:],'yo')
    plt.xlabel('T(time)')
    plt.ylabel('Amp')
    plt.title('Signal in Time Domain(CLASS-1)')
    plt.show()

    print("This is the BETA Band of ",df.columns[i])
    print('summery :(class-2) ',' (class-1)')

    print(pd.concat([pd.DataFrame(df[df.columns[i]][:499201].describe()),pd.DataFrame(df[df.columns[i]][499201:].describe())],axis=1))
# Out:
# This is the BETA Band of  AF3
# summery :(class-2)   (class-1)
#                 AF3           AF3
# count  4.992010e+05  4.223990e+05
# mean   1.578612e-05  1.502670e-05
# std    4.386772e-05  4.232846e-05
# min    2.508847e-08  1.668257e-08
# 25%    7.009625e-06  7.088728e-06
# 50%    1.141375e-05  1.157729e-05
# 75%    1.777402e-05  1.782357e-05
# max    3.721345e-03  5.295992e-03
# This is the BETA Band of  F7
# summery :(class-2)   (class-1)
#                  F7            F7
# count  4.992010e+05  4.223990e+05
# mean   2.345676e-05  1.797047e-05
# std    8.438674e-05  2.546626e-05
# min    3.988531e-08  1.967711e-08
# 25%    1.026445e-05  9.600676e-06
# 50%    1.666696e-05  1.514621e-05
# 75%    2.548141e-05  2.214827e-05
# max    1.041387e-02  2.271624e-03
# This is the BETA Band of  F3
# summery :(class-2)   (class-1)
#                  F3            F3
# count  4.992010e+05  4.223990e+05
# mean   1.590347e-05  1.615382e-05
# std    4.741470e-05  3.300156e-05
# min    2.194489e-08  8.877398e-09
# 25%    6.685188e-06  7.177562e-06
# 50%    1.098662e-05  1.177250e-05
# 75%    1.762461e-05  1.837805e-05
# max    4.039260e-03  2.517589e-03
# This is the BETA Band of  FC5
# summery :(class-2)   (class-1)
#                 FC5           FC5
# count  4.992010e+05  4.223990e+05
# mean   7.057340e-06  7.269305e-06
# std    2.368520e-05  1.515146e-05
# min    6.570502e-09  1.884203e-08
# 25%    3.236769e-06  3.398419e-06
# 50%    5.188947e-06  5.524145e-06
# 75%    7.852117e-06  8.504694e-06
# max    3.197714e-03  1.552719e-03
# This is the BETA Band of  T7
# summery :(class-2)   (class-1)
#                  T7            T7
# count  4.992010e+05  4.223990e+05
# mean   1.537458e-05  1.647468e-05
# std    4.481890e-05  4.023717e-05
# min    1.090522e-08  2.167588e-08
# 25%    6.672509e-06  7.171093e-06
# 50%    1.086323e-05  1.178334e-05
# 75%    1.695333e-05  1.853333e-05
# max    5.095910e-03  3.465436e-03
# This is the BETA Band of  P7
# summery :(class-2)   (class-1)
#                  P7            P7
# count  4.992010e+05  4.223990e+05
# mean   9.717658e-06  1.073839e-05
# std    2.461757e-05  2.196088e-05
# min    5.849082e-09  6.807032e-09
# 25%    4.358054e-06  4.696991e-06
# 50%    7.113072e-06  7.621291e-06
# 75%    1.091700e-05  1.186332e-05
# max    2.342335e-03  2.296515e-03
# This is the BETA Band of  O1
# summery :(class-2)   (class-1)
#                  O1            O1
# count  4.992010e+05  4.223990e+05
# mean   1.528934e-05  1.558460e-05
# std    3.116272e-05  4.284013e-05
# min    1.758168e-08  2.445377e-09
# 25%    6.644098e-06  7.076757e-06
# 50%    1.082194e-05  1.156648e-05
# 75%    1.685545e-05  1.782914e-05
# max    2.664806e-03  4.033921e-03
# This is the BETA Band of  O2
# summery :(class-2)   (class-1)
#                  O2            O2
# count  4.992010e+05  4.223990e+05
# mean   4.692627e-06  4.623725e-06
# std    1.956908e-05  6.905847e-06
# min    4.268285e-09  1.715045e-09
# 25%    2.035421e-06  2.140336e-06
# 50%    3.287606e-06  3.460134e-06
# 75%    4.975932e-06  5.299975e-06
# max    2.576709e-03  5.042947e-04
# This is the BETA Band of  P8
# summery :(class-2)   (class-1)
#                  P8            P8
# count  4.992010e+05  4.223990e+05
# mean   8.530474e-06  1.033839e-05
# std    2.698087e-05  3.531401e-05
# min    1.189418e-08  9.338530e-09
# 25%    3.650625e-06  3.834688e-06
# 50%    5.887803e-06  6.235268e-06
# 75%    8.992795e-06  9.558818e-06
# max    3.456462e-03  1.819363e-03
# This is the BETA Band of  T8
# summery :(class-2)   (class-1)
#                  T8            T8
# count  4.992010e+05  4.223990e+05
# mean   5.211436e-06  6.320028e-06
# std    1.557106e-05  1.318768e-05
# min    1.877074e-09  7.671410e-09
# 25%    2.172270e-06  2.443383e-06
# 50%    3.515672e-06  4.016184e-06
# 75%    5.438013e-06  6.433899e-06
# max    1.427233e-03  1.158670e-03
# This is the BETA Band of  FC6
# summery :(class-2)   (class-1)
#                 FC6           FC6
# count  4.992010e+05  4.223990e+05
# mean   1.548912e-05  1.569158e-05
# std    4.668268e-05  2.755957e-05
# min    1.550825e-08  2.018180e-08
# 25%    7.431227e-06  7.808098e-06
# 50%    1.183843e-05  1.247283e-05
# 75%    1.763764e-05  1.883310e-05
# max    4.599894e-03  2.641847e-03
# This is the BETA Band of  F4
# summery :(class-2)   (class-1)
#                  F4            F4
# count  4.992010e+05  4.223990e+05
# mean   1.742509e-05  1.784382e-05
# std    6.138980e-05  3.839087e-05
# min    3.326368e-09  3.141395e-08
# 25%    7.651771e-06  7.999183e-06
# 50%    1.230594e-05  1.298146e-05
# 75%    1.855198e-05  2.004776e-05
# max    7.050820e-03  2.820845e-03
# This is the BETA Band of  F8
# summery :(class-2)   (class-1)
#                  F8            F8
# count  4.992010e+05  4.223990e+05
# mean   1.559289e-05  2.242229e-05
# std    4.596712e-05  5.405186e-05
# min    4.380961e-09  4.646059e-09
# 25%    6.003539e-06  6.435197e-06
# 50%    9.623636e-06  1.053870e-05
# 75%    1.458067e-05  1.723327e-05
# max    5.866392e-03  3.942263e-03
# This is the BETA Band of  AF4
# summery :(class-2)   (class-1)
#                 AF4           AF4
# count  4.992010e+05  4.223990e+05
# mean   2.184021e-05  2.346475e-05
# std    4.187664e-05  3.624199e-05
# min    4.482877e-08  3.610785e-08
# 25%    1.080347e-05  1.084158e-05
# 50%    1.728454e-05  1.735826e-05
# 75%    2.582328e-05  2.615669e-05
# max    3.593008e-03  3.777803e-03

# %%
b,a = signal.butter(10,[12*(2*np.pi),38*(2*np.pi)],btype='bandpass',analog=True,output='ba')

# %%
for i in range(len(df.columns)):
    plt.figure(figsize=(17,5))
    plt.subplot(1,3,1)
    
    w2,h2 = signal.freqs(b,a,worN=499201)
    y2 = np.abs(fft(np.array(df[df.columns[i]][:499201]))*h2)
    plt.plot(w2,y2,'y',label='class-2')
    plt.xlabel("W(rad/s)")
    plt.ylabel("Amp")
    plt.title('Amplitude spectrum(class-2)')
    
    plt.subplot(1,3,2)
    w1,h1 = signal.freqs(b,a,worN=(921600-499201))
    y1 = np.abs(fft(np.array(df[df.columns[i]][499201:]))*h1)
    plt.plot(w1,y1,'b',label='class-1')
    plt.xlabel("W(rad/s)")
    plt.title('Amplitude spectrum(class-1)')
  
    plt.subplot(1,3,3)
    plt.plot(w2,y2,'y',label='class-2')
    plt.plot(w1,y1,'b',label='class-1')
    plt.xlabel("W(rad/s)")
    plt.title('Amplitude spectrum')
    plt.legend(loc='best')
    
    plt.show()
    print("This is the BETA Band of ",df.columns[i])
# Out:
# This is the BETA Band of  AF3
# This is the BETA Band of  F7
# This is the BETA Band of  F3
# This is the BETA Band of  FC5
# This is the BETA Band of  T7
# This is the BETA Band of  P7
# This is the BETA Band of  O1
# This is the BETA Band of  O2
# This is the BETA Band of  P8
# This is the BETA Band of  T8
# This is the BETA Band of  FC6
# This is the BETA Band of  F4
# This is the BETA Band of  F8
# This is the BETA Band of  AF4

# %%
for i in range(len(df.columns)):
    plt.figure(figsize=(17,5))
    
    plt.subplot(1,3,1)
    w2,h2 = signal.freqs(b,a,worN=499201)
    y2 = 20*np.log10(np.abs(fft(np.array(df[df.columns[i]][:499201]))*h2)**2)
    plt.plot(w2,y2,'y',label='class-2')
    plt.xlabel("W(rad/s)")
    plt.ylabel("Amp(in db(20*log10))")
    plt.title('PSD(class-2)')
    
    plt.subplot(1,3,2)
    w1,h1 = signal.freqs(b,a,worN=(921600-499201))
    y1 = 20*np.log10(np.abs(fft(np.array(df[df.columns[i]][499201:]))*h1)**2)
    plt.plot(w1,y1,'b',label='class-1')
    plt.xlabel("W(rad/s)")
    plt.title('PSD(class-1)')
  
    plt.subplot(1,3,3)
    plt.plot(w2,y2,'y',label='class-2')
    plt.plot(w1,y1,'b',label='class-1')
    plt.xlabel("W(rad/s)")
    plt.title('PSD')
    plt.legend(loc='best')
    
    plt.show()
    print('This is the PSD of BETA Band of ',df.columns[i])
# Out:
# This is the PSD of BETA Band of  AF3
# This is the PSD of BETA Band of  F7
# This is the PSD of BETA Band of  F3
# This is the PSD of BETA Band of  FC5
# This is the PSD of BETA Band of  T7
# This is the PSD of BETA Band of  P7
# This is the PSD of BETA Band of  O1
# This is the PSD of BETA Band of  O2
# This is the PSD of BETA Band of  P8
# This is the PSD of BETA Band of  T8
# This is the PSD of BETA Band of  FC6
# This is the PSD of BETA Band of  F4
# This is the PSD of BETA Band of  F8
# This is the PSD of BETA Band of  AF4

# %%
for i in range(len(df.columns)):
    plt.figure(figsize=(20,5))
    plt.subplot(1,2,1)
    
    w2,h2 = signal.freqs(b,a,worN=499201)
    y2 = np.angle(fft(np.array(df[df.columns[i]][:499201]))*h2)
    plt.plot(w2,y2,'y')
    plt.xlabel('W(rad/sec)')
    plt.ylabel('Phase(rad)')
    plt.title('Phase spectrum(class-2)')
    
    plt.subplot(1,2,2)
    w1,h1 = signal.freqs(b,a,worN=(921600-499201))
    y1 = np.angle(fft(np.array(df[df.columns[i]][499201:]))*h1)
    plt.plot(w1,y1,'b')
    plt.xlabel("W(rad/s)")
    plt.ylabel('Phase(rad)')
    plt.title('Phase spectrum(class-1)')
    
    plt.show()
    print("This is the BETA Band of ",df.columns[i])
# Out:
# This is the BETA Band of  AF3
# This is the BETA Band of  F7
# This is the BETA Band of  F3
# This is the BETA Band of  FC5
# This is the BETA Band of  T7
# This is the BETA Band of  P7
# This is the BETA Band of  O1
# This is the BETA Band of  O2
# This is the BETA Band of  P8
# This is the BETA Band of  T8
# This is the BETA Band of  FC6
# This is the BETA Band of  F4
# This is the BETA Band of  F8
# This is the BETA Band of  AF4
